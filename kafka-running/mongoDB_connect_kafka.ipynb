# %%
pip install pymongo[srv]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb+srv://hoangphu7122002:071202@cluster0.obabt.mongodb.net/myFirstDatabase?retryWrites=true&w=majority')

# %%
db = client.get_database('youtube_crawling')

# %%
records = db["myfile_20220407-114633_"]

# %%
records.find_one()
# Out:
# {'_id': ObjectId('624e986afcd464a9afb74042'),
#  'user_name': 'Nhặt',
#  'time_post': '2 years ago',
#  'comment_post': 'Nhạc của Thịnh Suy giai điệu bắt tai ngay từ lần đầu nghe, nghiện mất rồi :(',
#  'num_like': '1.4K',
#  'num_subcomments': '8'}

# %%
list(records.find())
# Out:
# [{'_id': ObjectId('624e986afcd464a9afb74042'),
#   'user_name': 'Nhặt',
#   'time_post': '2 years ago',
#   'comment_post': 'Nhạc của Thịnh Suy giai điệu bắt tai ngay từ lần đầu nghe, nghiện mất rồi :(',
#   'num_like': '1.4K',
#   'num_subcomments': '8'},
#  {'_id': ObjectId('624e986afcd464a9afb74043'),
#   'user_name': 'Long Bee',
#   'time_post': '1 year ago',
#   'comment_post': 'Đừng hỏi:"2020 ai còn xem không" vì chúng ta vẫn luôn ở đây và nghe bài hát này',
#   'num_like': '2.7K',
#   'num_subcomments': '147'},
#  {'_id': ObjectId('624e986afcd464a9afb74044'),
#   'user_name': 'Santelmo',
#   'time_post': '2 months ago',
#   'comment_post': '1:58 Ma-traffic talaga diyan sa Quiapo tsk tsk tsk',
#   'num_like': '2',
#   'num_subcomments': '0'},
#  {'_id': ObjectId('624e986afcd464a9afb74045'),
#   'user_name': 'Thu Hương',
#   'time_post': '1 year ago',
#   'comment_post': 'Ơ t còn tưởng bài này mới ra ý chứ :(((',
#   'num_like': '529',
#   'num_subcomments': '7'},
# ...

# %%
records.find_one({'num_like': '1'})
# Out:
# {'_id': ObjectId('624e986afcd464a9afb74046'),
#  'user_name': 'Dung Vu',
#  'time_post': '2 months ago',
#  'comment_post': 'oke',
#  'num_like': '1',
#  'num_subcomments': '0'}

# %%
test = records.find_one()

# %%
test
# Out:
# {'_id': ObjectId('624e986afcd464a9afb74042'),
#  'user_name': 'Nhặt',
#  'time_post': '2 years ago',
#  'comment_post': 'Nhạc của Thịnh Suy giai điệu bắt tai ngay từ lần đầu nghe, nghiện mất rồi :(',
#  'num_like': '1.4K',
#  'num_subcomments': '8'}

# %% [markdown]
# **kafka**

# %%
test_kafka = list(records.find())[:10]

# %%
print(type(test_kafka[0]))
# Out:
# <class 'dict'>

# %%
from kafka import KafkaProducer
from time import sleep
import json
from datetime import datetime
from bson import json_util

# %%
producer = KafkaProducer(bootstrap_servers=['localhost:9092'],api_version=(0,10,1))

# %%
for i in range(10):
    producer.send('demo',json.dumps(test_kafka[i], default=json_util.default).encode('utf-8'))
    sleep(0.5)
