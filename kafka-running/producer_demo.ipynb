# %%
from kafka import KafkaProducer
from datetime import datetime
import time
from json import dumps
import random

# pip install kafka-python

KAFKA_TOPIC_NAME_CONS = "test-topic"
KAFKA_BOOTSTRAP_SERVERS_CONS = 'localhost:9092'

if __name__ == "__main__":
    print("Kafka Producer Application Started ... ")

    kafka_producer_obj = KafkaProducer(bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS_CONS,
                                       value_serializer=lambda x: dumps(x).encode('utf-8'))

    product_name_list = ["Laptop", "Desktop Computer", "Mobile Phone", "Wrist Band", "Wrist Watch", "LAN Cable",
                         "HDMI Cable", "TV", "TV Stand", "Text Books", "External Hard Drive", "Pen Drive", "Online Course"]

    order_card_type_list = ["Visa", "MasterCard", "Maestro"]

    country_name_city_name_list = ["Sydney,Australia", "Florida,United States", "New York City,United States",
                                   "Paris,France", "Colombo,Sri Lanka", "Dhaka,Bangladesh", "Islamabad,Pakistan",
                                   "Beijing,China", "Rome,Italy", "Berlin,Germany", "Ottawa,Canada",
                                   "London,United Kingdom", "Jerusalem,Israel", "Bangkok,Thailand",
                                   "Chennai,India", "Bangalore,India", "Mumbai,India", "Pune,India",
                                   "New Delhi,Inida", "Hyderabad,India", "Kolkata,India", "Singapore,Singapore"]

    ecommerce_website_name_list = ["www.datamaking.com", "www.amazon.com", "www.flipkart.com", "www.snapdeal.com", "www.ebay.com"]

    message_list = []
    message = None
    for i in range(500):
        i = i + 1
        message = {}
        print("Preparing message: " + str(i))
        event_datetime = datetime.now()

        message["order_id"] = i
        message["order_product_name"] = random.choice(product_name_list)
        message["order_card_type"] = random.choice(order_card_type_list)
        message["order_amount"] = round(random.uniform(5.5, 555.5), 2)
        message["order_datetime"] = event_datetime.strftime("%Y-%m-%d %H:%M:%S")
        country_name = None
        city_name = None
        country_name_city_name = None
        country_name_city_name = random.choice(country_name_city_name_list)
        country_name = country_name_city_name.split(",")[1]
        city_name = country_name_city_name.split(",")[0]
        message["order_country_name"] = country_name
        message["order_city_name"] = city_name
        message["order_ecommerce_website_name"] = random.choice(ecommerce_website_name_list)

        # order_id,order_product_name,order_card_type,order_amount,order_datetime,order_country_name,order_city_name,order_ecommerce_website_name
        # print("Message Type: ", type(message))
        print("Message: ", message)
        #message_list.append(message)
        kafka_producer_obj.send(KAFKA_TOPIC_NAME_CONS, message)
        time.sleep(1)

    # print(message_list)

    print("Kafka Producer Application Completed. ")
# Out:
# Kafka Producer Application Started ...
# Preparing message: 1
# Message:  {'order_id': 1, 'order_product_name': 'Pen Drive', 'order_card_type': 'Maestro', 'order_amount': 221.46, 'order_datetime': '2022-04-28 01:44:02', 'order_country_name': 'India', 'order_city_name': 'Chennai', 'order_ecommerce_website_name': 'www.amazon.com'}
# Preparing message: 2
# Message:  {'order_id': 2, 'order_product_name': 'Text Books', 'order_card_type': 'MasterCard', 'order_amount': 287.44, 'order_datetime': '2022-04-28 01:44:03', 'order_country_name': 'India', 'order_city_name': 'Hyderabad', 'order_ecommerce_website_name': 'www.snapdeal.com'}
# Preparing message: 3
# Message:  {'order_id': 3, 'order_product_name': 'Text Books', 'order_card_type': 'Maestro', 'order_amount': 547.31, 'order_datetime': '2022-04-28 01:44:04', 'order_country_name': 'France', 'order_city_name': 'Paris', 'order_ecommerce_website_name': 'www.amazon.com'}
# Preparing message: 4
# Message:  {'order_id': 4, 'order_product_name': 'Mobile Phone', 'order_card_type': 'MasterCard', 'order_amount': 338.13, 'order_datetime': '2022-04-28 01:44:05', 'order_country_name': 'United States', 'order_city_name': 'New York City', 'order_ecommerce_website_name': 'www.datamaking.com'}
# Preparing message: 5
# Message:  {'order_id': 5, 'order_product_name': 'LAN Cable', 'order_card_type': 'MasterCard', 'order_amount': 130.79, 'order_datetime': '2022-04-28 01:44:06', 'order_country_name': 'Singapore', 'order_city_name': 'Singapore', 'order_ecommerce_website_name': 'www.datamaking.com'}
# Preparing message: 6
# Message:  {'order_id': 6, 'order_product_name': 'TV', 'order_card_type': 'Maestro', 'order_amount': 117.91, 'order_datetime': '2022-04-28 01:44:07', 'order_country_name': 'China', 'order_city_name': 'Beijing', 'order_ecommerce_website_name': 'www.amazon.com'}
# Preparing message: 7
# Message:  {'order_id': 7, 'order_product_name': 'LAN Cable', 'order_card_type': 'MasterCard', 'order_amount': 210.34, 'order_datetime': '2022-04-28 01:44:08', 'order_country_name': 'Singapore', 'order_city_name': 'Singapore', 'order_ecommerce_website_name': 'www.snapdeal.com'}
# Preparing message: 8
# Message:  {'order_id': 8, 'order_product_name': 'Online Course', 'order_card_type': 'Visa', 'order_amount': 171.13, 'order_datetime': '2022-04-28 01:44:09', 'order_country_name': 'India', 'order_city_name': 'Kolkata', 'order_ecommerce_website_name': 'www.datamaking.com'}
# Preparing message: 9
# Message:  {'order_id': 9, 'order_product_name': 'LAN Cable', 'order_card_type': 'MasterCard', 'order_amount': 474.71, 'order_datetime': '2022-04-28 01:44:10', 'order_country_name': 'Sri Lanka', 'order_city_name': 'Colombo', 'order_ecommerce_website_name': 'www.flipkart.com'}
# Preparing message: 10
# Message:  {'order_id': 10, 'order_product_name': 'Pen Drive', 'order_card_type': 'Visa', 'order_amount': 230.08, 'order_datetime': '2022-04-28 01:44:11', 'order_country_name': 'India', 'order_city_name': 'Hyderabad', 'order_ecommerce_website_name': 'www.flipkart.com'}
# Preparing message: 11
# Message:  {'order_id': 11, 'order_product_name': 'External Hard Drive', 'order_card_type': 'Visa', 'order_amount': 93.81, 'order_datetime': '2022-04-28 01:44:12', 'order_country_name': 'France', 'order_city_name': 'Paris', 'order_ecommerce_website_name': 'www.snapdeal.com'}
# Preparing message: 12
# Message:  {'order_id': 12, 'order_product_name': 'External Hard Drive', 'order_card_type': 'Visa', 'order_amount': 109.16, 'order_datetime': '2022-04-28 01:44:13', 'order_country_name': 'India', 'order_city_name': 'Pune', 'order_ecommerce_website_name': 'www.ebay.com'}
# Preparing message: 13
# Message:  {'order_id': 13, 'order_product_name': 'HDMI Cable', 'order_card_type': 'Maestro', 'order_amount': 438.46, 'order_datetime': '2022-04-28 01:44:14', 'order_country_name': 'United States', 'order_city_name': 'New York City', 'order_ecommerce_website_name': 'www.snapdeal.com'}
# Preparing message: 14
# Message:  {'order_id': 14, 'order_product_name': 'TV', 'order_card_type': 'Maestro', 'order_amount': 333.68, 'order_datetime': '2022-04-28 01:44:15', 'order_country_name': 'France', 'order_city_name': 'Paris', 'order_ecommerce_website_name': 'www.ebay.com'}
# Preparing message: 15
# Message:  {'order_id': 15, 'order_product_name': 'Wrist Watch', 'order_card_type': 'Visa', 'order_amount': 411.83, 'order_datetime': '2022-04-28 01:44:16', 'order_country_name': 'Bangladesh', 'order_city_name': 'Dhaka', 'order_ecommerce_website_name': 'www.ebay.com'}
# Preparing message: 16
# Message:  {'order_id': 16, 'order_product_name': 'Desktop Computer', 'order_card_type': 'Maestro', 'order_amount': 183.07, 'order_datetime': '2022-04-28 01:44:17', 'order_country_name': 'Pakistan', 'order_city_name': 'Islamabad', 'order_ecommerce_website_name': 'www.datamaking.com'}
# Preparing message: 17
# Message:  {'order_id': 17, 'order_product_name': 'Laptop', 'order_card_type': 'Maestro', 'order_amount': 320.45, 'order_datetime': '2022-04-28 01:44:18', 'order_country_name': 'Canada', 'order_city_name': 'Ottawa', 'order_ecommerce_website_name': 'www.snapdeal.com'}
# Preparing message: 18
# Message:  {'order_id': 18, 'order_product_name': 'Wrist Watch', 'order_card_type': 'Visa', 'order_amount': 309.37, 'order_datetime': '2022-04-28 01:44:19', 'order_country_name': 'France', 'order_city_name': 'Paris', 'order_ecommerce_website_name': 'www.flipkart.com'}
# Preparing message: 19
# Message:  {'order_id': 19, 'order_product_name': 'LAN Cable', 'order_card_type': 'Visa', 'order_amount': 384.07, 'order_datetime': '2022-04-28 01:44:20', 'order_country_name': 'United Kingdom', 'order_city_name': 'London', 'order_ecommerce_website_name': 'www.amazon.com'}
# Preparing message: 20
# Message:  {'order_id': 20, 'order_product_name': 'Wrist Band', 'order_card_type': 'MasterCard', 'order_amount': 499.76, 'order_datetime': '2022-04-28 01:44:21', 'order_country_name': 'Pakistan', 'order_city_name': 'Islamabad', 'order_ecommerce_website_name': 'www.ebay.com'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 12>()
#      58     #message_list.append(message)
#      59     kafka_producer_obj.send(KAFKA_TOPIC_NAME_CONS, message)
# ---> 60     time.sleep(1)
#      62 # print(message_list)
#      64 print("Kafka Producer Application Completed. ")
#
# KeyboardInterrupt:
